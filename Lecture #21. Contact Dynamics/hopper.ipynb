# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate()
# Out:
#   Activating project at `g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #21. Contact Dynamics`

# %%
using LinearAlgebra
using PyPlot
using ForwardDiff
using Ipopt
using MathOptInterface
const MOI = MathOptInterface;

# %%
Nx = 8     # number of state [body x, z, foot x, z, body vx, body vz, foot vx, foot vz]
Nu = 2     # number of controls [fx, fz]
Tfinal = 4.4 # final time
h = 0.1 #10 hz
Nm = 5 #number of steps in each mode
Nt = Int(ceil(Tfinal/h)+1)   # number of time steps
Nmodes = Int(ceil(Nt/Nm))
thist = Array(range(0,h*(Nt-1), step=h));
n_nlp = Nx*Nt + Nu*(Nt-1) # number of decision variables
c_init_inds = 1:Nx
c_term_inds = (c_init_inds[end]+1):(c_init_inds[end]+Nx)
c_dyn_inds = (c_term_inds[end]+1):(c_term_inds[end]+Nx*(Nt-1))
c_stance_inds = (c_dyn_inds[end]+1):(c_dyn_inds[end]+Int(ceil(Nmodes/2)*Nm))
c_length_inds = (c_stance_inds[end]+1):(c_stance_inds[end]+Nt)
m_nlp = c_length_inds[end]
# Out:
# 441

# %%
#Hopper Dynamics
g = 9.81
m1 = 5.0 #body mass
m2 = 1.0 #foot mass
ℓ_min = 0.5 #minimum length
ℓ_max = 1.5 #maximum length

function flight_dynamics(x,u)
    M = Diagonal([m1 m1 m2 m2])
    
    r1 = x[1:2]
    r2 = x[3:4]
    v = x[5:8]
    
    ℓ1 = (r1[1]-r2[1])/norm(r1-r2)
    ℓ2 = (r1[2]-r2[2])/norm(r1-r2)
    B = [ℓ1  ℓ2;
         ℓ2 -ℓ1;
        -ℓ1 -ℓ2;
        -ℓ2  ℓ1]
    
    v̇ = [0; -g; 0; -g] + M\(B*u)
    
    ẋ = [v; v̇]
end

function stance_dynamics(x,u)
    m1 = 5.0 #body mass
    m2 = 1.0 #foot mass
    M = Diagonal([m1 m1 m2 m2])
    g = 9.81
    
    r1 = x[1:2]
    r2 = x[3:4]
    v = x[5:8]
    
    ℓ1 = (r1[1]-r2[1])/norm(r1-r2)
    ℓ2 = (r1[2]-r2[2])/norm(r1-r2)
    B = [ℓ1  ℓ2;
         ℓ2 -ℓ1;
         0   0;
         0   0]
    
    v̇ = [0; -g; 0; 0] + M\(B*u)
    
    ẋ = [v; v̇]
end

function flight_dynamics_rk4(x,u)
    #RK4 integration with zero-order hold on u
    f1 = flight_dynamics(x, u)
    f2 = flight_dynamics(x + 0.5*h*f1, u)
    f3 = flight_dynamics(x + 0.5*h*f2, u)
    f4 = flight_dynamics(x + h*f3, u)
    return x + (h/6.0)*(f1 + 2*f2 + 2*f3 + f4)
end

function stance_dynamics_rk4(x,u)
    #RK4 integration with zero-order hold on u
    f1 = stance_dynamics(x, u)
    f2 = stance_dynamics(x + 0.5*h*f1, u)
    f3 = stance_dynamics(x + 0.5*h*f2, u)
    f4 = stance_dynamics(x + h*f3, u)
    return x + (h/6.0)*(f1 + 2*f2 + 2*f3 + f4)
end

function jump_map(x)
    #Assume the foot experiences inelastic collisions
    xn = [x[1:6]; 0.0; 0.0]
    return xn
end
# Out:
# jump_map (generic function with 1 method)

# %%
# Cost weights
Q = Diagonal([1.0*ones(4); 1.0*ones(4)]);
R = 0.001;
Qn = Q;

# %%
function stage_cost(x,u,k)
    return 0.5*((x-xref[:,k])'*Q*(x-xref[:,k])) + 0.5*(u-uref)'*R*(u-uref)
end
function terminal_cost(x)
    return 0.5*((x-xref[:,end])'*Qn*(x-xref[:,end]))
end
# Out:
# terminal_cost (generic function with 1 method)

# %%
function cost(ztraj)
    z = reshape(ztraj[1:(end-Nx)],Nx+Nu,Nt-1)
    xtraj = [z[1:Nx,:] ztraj[end-(Nx-1):end]]
    utraj = z[(Nx+1):(Nx+Nu),:]
    J = 0.0
    for k = 1:(Nt-1)
        J += stage_cost(xtraj[:,k],utraj[:,k],k)
    end
    J += terminal_cost(xtraj[:,end])
    return J
end
# Out:
# cost (generic function with 1 method)

# %%
#Reference Trajectory
uref = [m1*g; 0.0]
xref = zeros(Nx,Nt)
xref[1,:] .= LinRange(-1.0,1.0,Nt)
xref[2,:] .= 1.0 .+ 0.5.*sin.(2*pi/10.0*(0:(Nt-1)));
xref[3,:] .= LinRange(-1.0,1.0,Nt)
xref[5,2:end-1] .= (2.0/Tfinal)*ones(Nt-2)
xref[7,2:end-1] .= (2.0/Tfinal)*ones(Nt-2);

# %%
plot(xref[2,:])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000017C886CD950>

# %%
function dynamics_constraint!(c,ztraj)
    d = reshape(view(c,c_dyn_inds),Nx,Nt-1)
    z = reshape(ztraj[1:(end-Nx)],Nx+Nu,Nt-1)
    xtraj = [z[1:Nx,:] ztraj[end-(Nx-1):end]]
    utraj = z[(Nx+1):(Nx+Nu),:]
    for k = 1:(Nmodes-1)
        if mod(k,2) == 1
            for j = 1:Nm
                s = (k-1)*Nm + j
                d[:,s] = stance_dynamics_rk4(xtraj[:,s],utraj[:,s]) - xtraj[:,s+1]
            end
        else
            for j = 1:(Nm-1)
                s = (k-1)*Nm + j
                d[:,s] = flight_dynamics_rk4(xtraj[:,s],utraj[:,s]) - xtraj[:,s+1]
            end
            s = k*Nm
            d[:,s] = jump_map(flight_dynamics_rk4(xtraj[:,s],utraj[:,s])) - xtraj[:,s+1]
        end
    end
    if mod(Nmodes,2) == 1
        for j = 1:(Nm-1)
            s = (Nmodes-1)*Nm + j
            d[:,s] = stance_dynamics_rk4(xtraj[:,s],utraj[:,s]) - xtraj[:,s+1]
        end
    else
        for j = 1:(Nm-1)
            s = (Nmodes-1)*Nm + j
            d[:,s] = flight_dynamics_rk4(xtraj[:,s],utraj[:,s]) - xtraj[:,s+1]
        end
    end
    
    return nothing
end
# Out:
# dynamics_constraint! (generic function with 1 method)

# %%
function stance_constraint!(c,ztraj)
    d = view(c,c_stance_inds)
    z = reshape(ztraj[1:(end-Nx)],Nx+Nu,Nt-1)
    xtraj = [z[1:Nx,:] ztraj[(end-(Nx-1)):end]]
    t = 1
    for k = 1:Nmodes
        if mod(k,2) == 1
            for j = 1:Nm
                s = (k-1)*Nm + j
                d[t] = xtraj[4,s]
                t += 1
            end
        end
            
    end
    return nothing
end
# Out:
# stance_constraint! (generic function with 1 method)

# %%
function length_constraint!(c,ztraj)
    d = view(c,c_length_inds)
    z = reshape(ztraj[1:(end-Nx)],Nx+Nu,Nt-1)
    xtraj = [z[1:Nx,:] ztraj[(end-(Nx-1)):end]]
    for k = 1:Nt
        d[k] = norm(xtraj[1:2,k] - xtraj[3:4,k])
    end
end
# Out:
# length_constraint! (generic function with 1 method)

# %%
function con!(c,ztraj)
    c[c_init_inds] .= ztraj[1:Nx] - xref[:,1] #initial state constraint
    c[c_term_inds] .= ztraj[(end-(Nx-1)):end] - xref[:,end] #terminal state constraint
    @views dynamics_constraint!(c,ztraj)
    @views stance_constraint!(c,ztraj)
    @views length_constraint!(c,ztraj)
end
# Out:
# con! (generic function with 1 method)

# %%
struct ProblemMOI <: MOI.AbstractNLPEvaluator
    n_nlp::Int
    m_nlp::Int
    idx_ineq
    obj_grad::Bool
    con_jac::Bool
    sparsity_jac
    sparsity_hess
    primal_bounds
    constraint_bounds
    hessian_lagrangian::Bool
end

function ProblemMOI(n_nlp,m_nlp;
        idx_ineq=c_length_inds,
        obj_grad=true,
        con_jac=true,
        sparsity_jac=sparsity_jacobian(n_nlp,m_nlp),
        sparsity_hess=sparsity_hessian(n_nlp,m_nlp),
        primal_bounds=primal_bounds(n_nlp),
        constraint_bounds=constraint_bounds(m_nlp,idx_ineq=idx_ineq),
        hessian_lagrangian=false)

    ProblemMOI(n_nlp,m_nlp,
        idx_ineq,
        obj_grad,
        con_jac,
        sparsity_jac,
        sparsity_hess,
        primal_bounds,
        constraint_bounds,
        hessian_lagrangian)
end

function primal_bounds(n)
    x_l = -Inf*ones(n)
    x_u = Inf*ones(n)
    return x_l, x_u
end

function constraint_bounds(m; idx_ineq=(1:0))
    c_l = zeros(m)
    c_l[idx_ineq] .= ℓ_min

    c_u = zeros(m)
    c_u[idx_ineq] .= ℓ_max
    return c_l, c_u
end

function row_col!(row,col,r,c)
    for cc in c
        for rr in r
            push!(row,convert(Int,rr))
            push!(col,convert(Int,cc))
        end
    end
    return row, col
end

function sparsity_jacobian(n,m)

    row = Vector{Int}()
    col = Vector{Int}()

    r = 1:m
    c = 1:n

    row_col!(row,col,r,c)

    return collect(zip(row,col))
end

function sparsity_hessian(n,m)

    row = Vector{Int}()
    col = Vector{Int}()

    r = 1:m
    c = 1:n

    row_col!(row,col,r,c)

    return collect(zip(row,col))
end

function MOI.eval_objective(prob::MOI.AbstractNLPEvaluator, x)
    cost(x)
end

function MOI.eval_objective_gradient(prob::MOI.AbstractNLPEvaluator, grad_f, x)
    ForwardDiff.gradient!(grad_f,cost,x)
    return nothing
end

function MOI.eval_constraint(prob::MOI.AbstractNLPEvaluator,g,x)
    con!(g,x)
    return nothing
end

function MOI.eval_constraint_jacobian(prob::MOI.AbstractNLPEvaluator, jac, x)
    ForwardDiff.jacobian!(reshape(jac,prob.m_nlp,prob.n_nlp), con!, zeros(prob.m_nlp), x)
    return nothing
end

function MOI.features_available(prob::MOI.AbstractNLPEvaluator)
    return [:Grad, :Jac]
end

MOI.initialize(prob::MOI.AbstractNLPEvaluator, features) = nothing
MOI.jacobian_structure(prob::MOI.AbstractNLPEvaluator) = prob.sparsity_jac

function solve(x0,prob::MOI.AbstractNLPEvaluator;
        tol=1.0e-6,c_tol=1.0e-6,max_iter=10000)
    x_l, x_u = prob.primal_bounds
    c_l, c_u = prob.constraint_bounds

    nlp_bounds = MOI.NLPBoundsPair.(c_l,c_u)
    block_data = MOI.NLPBlockData(nlp_bounds,prob,true)

    solver = Ipopt.Optimizer()
    solver.options["max_iter"] = max_iter
    solver.options["tol"] = tol
    solver.options["constr_viol_tol"] = c_tol

    x = MOI.add_variables(solver,prob.n_nlp)

    for i = 1:prob.n_nlp
        MOI.add_constraint(solver, x[i], MOI.LessThan(x_u[i]))
        MOI.add_constraint(solver, x[i], MOI.GreaterThan(x_l[i]))
        MOI.set(solver, MOI.VariablePrimalStart(), x[i], x0[i])
    end

    # Solve the problem
    MOI.set(solver, MOI.NLPBlock(), block_data)
    MOI.set(solver, MOI.ObjectiveSense(), MOI.MIN_SENSE)
    MOI.optimize!(solver)

    # Get the solution
    res = MOI.get(solver, MOI.VariablePrimal(), x)

    return res
end
# Out:
# solve (generic function with 1 method)

# %%
#Guess
xguess = xref + 0.1*randn(Nx,Nt)
uguess = kron(ones(Nt-1)', uref) + 0.1*randn(Nu,Nt-1)
z0 = [reshape([xguess[:,1:(Nt-1)]; uguess],(Nx+Nu)*(Nt-1),1); xguess[:,end]];

# %%
prob = ProblemMOI(n_nlp,m_nlp)
z_sol = solve(z0,prob) # solve
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:   177408
# Number of nonzeros in inequality constraint Jacobian.:    20160
# Number of nonzeros in Lagrangian Hessian.............:        0
# BoundsError: attempt to access 2×44 Matrix{ForwardDiff.Dual{ForwardDiff.Tag{typeof(con!), Float64}, Float64, 12}} at index [1:2, 45]
#
# Stacktrace:
#   [1] throw_boundserror(A::Matrix{ForwardDiff.Dual{…}}, I::Tuple{Base.Slice{…}, Int64})
#     @ Base .\abstractarray.jl:737
#   [2] checkbounds
#     @ .\abstractarray.jl:702 [inlined]
#   [3] _getindex
#     @ .\multidimensional.jl:888 [inlined]
#   [4] getindex(::Matrix{ForwardDiff.Dual{ForwardDiff.Tag{typeof(con!), Float64}, Float64, 12}}, ::Function, ::Int64)
#     @ Base .\abstractarray.jl:1290
#   [5] dynamics_constraint!(c::Vector{ForwardDiff.Dual{…}}, ztraj::Vector{ForwardDiff.Dual{…}})
#     @ Main .\In[10]:24
#   [6] con!(c::Vector{ForwardDiff.Dual{…}}, ztraj::Vector{ForwardDiff.Dual{…}})
#     @ Main .\In[13]:4
#   [7] chunk_mode_jacobian!(result::Base.ReshapedArray{…}, f!::typeof(con!), y::Vector{…}, x::Vector{…}, cfg::ForwardDiff.JacobianConfig{…})
#     @ ForwardDiff C:\Users\ggory\.julia\packages\ForwardDiff\UBbGT\src\jacobian.jl:187
#   [8] jacobian!
#     @ C:\Users\ggory\.julia\packages\ForwardDiff\UBbGT\src\jacobian.jl:84 [inlined]
#   [9] jacobian!(result::Base.ReshapedArray{…}, f!::typeof(con!), y::Vector{…}, x::Vector{…}, cfg::ForwardDiff.JacobianConfig{…})
#     @ ForwardDiff C:\Users\ggory\.julia\packages\ForwardDiff\UBbGT\src\jacobian.jl:79
#  [10] jacobian!(result::Base.ReshapedArray{…}, f!::typeof(con!), y::Vector{…}, x::Vector{…})
#     @ ForwardDiff C:\Users\ggory\.julia\packages\ForwardDiff\UBbGT\src\jacobian.jl:79
#  [11] eval_constraint_jacobian(prob::ProblemMOI, jac::SubArray{Float64, 1, Vector{…}, Tuple{…}, true}, x::Vector{Float64})
#     @ Main .\In[14]:101
#  [12] eval_constraint_jacobian(model::Ipopt.Optimizer, values::Vector{Float64}, x::Vector{Float64})
#     @ Ipopt C:\Users\ggory\.julia\packages\Ipopt\pTfZ6\src\MOI_wrapper.jl:907
#  [13] (::Ipopt.var"#eval_jac_g_cb#10"{…})(x::Vector{…}, rows::Vector{…}, cols::Vector{…}, values::Vector{…})
#     @ Ipopt C:\Users\ggory\.julia\packages\Ipopt\pTfZ6\src\MOI_wrapper.jl:989
#  [14] _Eval_Jac_G_CB(n::Int32, x_ptr::Ptr{…}, ::Int32, ::Int32, nele_jac::Int32, iRow::Ptr{…}, jCol::Ptr{…}, values_ptr::Ptr{…}, user_data::Ptr{…})
#     @ Ipopt C:\Users\ggory\.julia\packages\Ipopt\pTfZ6\src\C_wrapper.jl:97
#  [15] (::Ipopt.var"#5#6"{IpoptProblem, Base.RefValue{Float64}})()
#     @ Ipopt C:\Users\ggory\.julia\packages\Ipopt\pTfZ6\src\C_wrapper.jl:407
#  [16] disable_sigint
#     @ .\c.jl:473 [inlined]
#  [17] IpoptSolve
#     @ C:\Users\ggory\.julia\packages\Ipopt\pTfZ6\src\C_wrapper.jl:406 [inlined]
#  [18] optimize!(model::Ipopt.Optimizer)
#     @ Ipopt C:\Users\ggory\.julia\packages\Ipopt\pTfZ6\src\MOI_wrapper.jl:1131
#  [19] solve(x0::Matrix{Float64}, prob::ProblemMOI; tol::Float64, c_tol::Float64, max_iter::Int64)
#     @ Main .\In[14]:136
#  [20] solve(x0::Matrix{Float64}, prob::ProblemMOI)
#     @ Main .\In[14]:112
#  [21] top-level scope
#     @ In[16]:2
# Some type information was truncated. Use `show(err)` to see complete types.

# %%
z = reshape(z_sol[1:(end-Nx)],Nx+Nu,Nt-1)
xtraj = [z[1:Nx,:] z_sol[end-(Nx-1):end]]
utraj = z[(Nx+1):(Nx+Nu),:];

# %%
plot(thist,xtraj[2,:])
plot(thist,xtraj[4,:])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x000001D504D40B90>

# %%
plot(thist,xtraj[1,:])
plot(thist,xtraj[3,:])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x000001D504DD4550>

# %%
plot(thist[1:end-1],utraj[1,:])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x000001D504E37390>

# %%
plot(thist[1:end-1],utraj[2,:])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x000001D50E5F8A50>

# %%
#Set up visualizer
using Colors
using CoordinateTransformations
using GeometryBasics
using MeshCat
using Rotations
using StaticArrays

# Kinematics
kinematics(q) = [q[3], q[4]]

# Visualization
function visualize!(vis, q, Δt)

    # body radius
    r_body = 0.2
	# foot radius
    r_foot = 0.1

	# leg width
    r_leg = 0.5 * r_foot

	# set background to white
	setvisible!(vis["/Background"], true)
    setprop!(vis["/Background"], "top_color", RGBA(1.0, 1.0, 1.0, 1.0))
    setprop!(vis["/Background"], "bottom_color", RGBA(1.0, 1.0, 1.0, 1.0))
    setvisible!(vis["/Axes"], false)

	# create body
    setobject!(vis["body"], Sphere(Point3f(0),
        convert(Float32, r_body)),
        MeshPhongMaterial(color = RGBA(0, 1, 0, 1.0)))

	# create foot
    setobject!(vis["foot"], Sphere(Point3f(0),
        convert(Float32, r_foot)),
        MeshPhongMaterial(color = RGBA(1.0, 165.0 / 255.0, 0, 1.0)))

# 	# create leg
    n_leg = 100
    for i = 1:n_leg
        setobject!(vis["leg$i"], Sphere(Point3f(0),
            convert(Float32, r_leg)),
            MeshPhongMaterial(color = RGBA(0, 0, 0, 1.0)))
    end

    p_leg = [zeros(3) for i = 1:n_leg]

	# animation
    anim = MeshCat.Animation(vis; fps=convert(Int, floor(1.0 / Δt)))

    for t = 1:length(q)
        p_body = [q[t][1], 0.0, q[t][2]]
        p_foot = [kinematics(q[t])[1], 0.0, kinematics(q[t])[2]]

        dir = [q[t][3] - q[t][1]; q[t][4] - q[t][2]]
        dir = dir ./ norm(dir)
        r_range = range(0, stop = sqrt((q[t][1] - q[t][3])^2.0 + (q[t][2] - q[t][4])^2.0), length = n_leg)
        for i = 1:n_leg
            p_leg[i] = [q[t][1] + r_range[i] * dir[1], 0.0, q[t][2] + r_range[i] * dir[2]]
        end
        
        z_shift = [0.0; 0.0; r_foot]

        MeshCat.atframe(anim, t) do
            settransform!(vis["body"], Translation(p_body + z_shift))
            settransform!(vis["foot"], Translation(p_foot + z_shift))

            for i = 1:n_leg
                settransform!(vis["leg$i"], Translation(p_leg[i] + z_shift))
            end
        end
    end

    MeshCat.setanimation!(vis, anim)
end

vis = Visualizer()
render(vis)
# Out:
# [ Info: Precompiling CoordinateTransformations [150eb455-5306-5404-9cee-2592286d6298]
# [ Info: Precompiling ForwardDiffStaticArraysExt [b74fd6d0-9da7-541f-a07d-1b6af30a262f]
# [ Info: Precompiling StaticArraysStatisticsExt [3453fcb0-342e-5e4a-a93b-f2e19ba3ba0f]
# [ Info: Precompiling GeometryBasics [5c1252a2-5f33-56bf-86c9-59e7332b4326]
# [ Info: Precompiling MeshCat [283c5d60-a78f-5afe-a0af-af636b173e11]
# [ Info: Listening on: 127.0.0.1:8700, thread id: 1
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# └ http://127.0.0.1:8700
# [ Info: Server on 127.0.0.1:8700 closing
# [ Info: MeshCat server closed.
# [ Info: Listening on: 127.0.0.1:8700, thread id: 1
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# └ http://127.0.0.1:8700
# MeshCat.DisplayedVisualizer(MeshCat.CoreVisualizer(MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), Set{HTTP.WebSockets.WebSocket}(), ip"127.0.0.1", 8700, HTTP.Servers.Server{HTTP.Servers.Listener{Nothing, Sockets.TCPServer}}(HTTP.Servers.Listener{Nothing, Sockets.TCPServer}(Sockets.InetAddr{Sockets.IPv4}(ip"127.0.0.1", 8700), "127.0.0.1", "8700", nothing, Sockets.TCPServer(Base.Libc.WindowsRawSocket(0x0000000000002380) active)), nothing, Set{HTTP.Connections.Connection}(), Task (runnable) @0x000001d50d9d9370, ReentrantLock(nothing, 0x00000000, 0x00, Base.GenericCondition{Base.Threads.SpinLock}(Base.IntrusiveLinkedList{Task}(nothing, nothing), Base.Threads.SpinLock(0)), (0, 2012698837424, 2012698837712))), MeshCat.AnimationContext[]))

# %%
q = [SVector{4}(x[1:4]) for x in eachcol(xtraj)];
visualize!(vis, q, h)
