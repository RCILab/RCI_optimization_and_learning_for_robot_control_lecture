# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate()
Pkg.add("PyPlot")
Pkg.add("ControlSystems")
Pkg.add("MeshCat")
Pkg.add("ForwardDiff")
Pkg.add("OSQP")
# Out:
#   Activating project at `g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC`
#    Resolving package versions...
#     Updating `G:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\Project.toml`
# ⌅ [150eb455] ↓ CoordinateTransformations v0.6.4 ⇒ v0.6.3
#   [d330b81b] + PyPlot v2.11.6
#     Updating `G:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\Manifest.toml`
# ⌅ [4fba245c] ↓ ArrayInterface v7.22.0 ⇒ v7.7.1
#   [8f4d0f93] + Conda v1.10.3
# ⌅ [187b0558] ↓ ConstructionBase v1.6.0 ⇒ v1.5.8
# ⌅ [150eb455] ↓ CoordinateTransformations v0.6.4 ⇒ v0.6.3
#   [9a962f9c] + DataAPI v1.16.0
# ⌅ [411431e0] ↓ Extents v0.1.6 ⇒ v0.1.4
# ⌅ [6a86dc24] ↓ FiniteDiff v2.29.0 ⇒ v2.22.0
#   [68eda718] + GeoFormatTypes v0.4.5
# ⌅ [cf35fbd7] + GeoInterface v1.4.1
# ⌅ [5c1252a2] ↓ GeometryBasics v0.5.10 ⇒ v0.5.9
# ⌅ [92d709cd] ↓ IrrationalConstants v0.2.6 ⇒ v0.2.4
#   [682c06a0] + JSON v1.4.0
#   [b964fa9f] + LaTeXStrings v1.4.0
# ⌅ [2ab3a3ac] ↓ LogExpFunctions v0.3.29 ⇒ v0.3.28
# ⌅ [77ba4419] ↓ NaNMath v1.1.3 ⇒ v1.0.3
#   [69de0a69] + Parsers v2.8.3
#   [21216c6a] ↑ Preferences v1.5.1 ⇒ v1.5.2
#   [438e738f] + PyCall v1.96.4
#   [d330b81b] + PyPlot v2.11.6
# ⌅ [276daf66] ↓ SpecialFunctions v2.7.1 ⇒ v2.5.1
#   [ec057cc2] + StructUtils v2.6.3
#   [81def892] + VersionParsing v1.3.0
#   [44cfe95a] ↓ Pkg v1.10.0 ⇒ v1.9.2
#   [2f01184e] ~ SparseArrays v1.10.0 ⇒
#   [10745b16] ↓ Statistics v1.10.0 ⇒ v1.9.0
#   [4607b0f0] + SuiteSparse
#   [e66e0078] ↓ CompilerSupportLibraries_jll v1.1.1+0 ⇒ v1.0.5+0
#   [e37daf67] - LibGit2_jll v1.6.4+0
#   [c8ffd9c3] ↓ MbedTLS_jll v2.28.2+1 ⇒ v2.28.2+0
#   [14a3606d] ↓ MozillaCACerts_jll v2023.1.10 ⇒ v2022.10.11
#   [4536629a] ↓ OpenBLAS_jll v0.3.23+4 ⇒ v0.3.21+4
#   [05823500] ↓ OpenLibm_jll v0.8.5+0 ⇒ v0.8.1+0
#   [efcefdf7] ↓ PCRE2_jll v10.42.0+1 ⇒ v10.42.0+0
#   [bea87d4a] ↓ SuiteSparse_jll v7.2.1+1 ⇒ v5.10.1+6
#   [83775a58] ↓ Zlib_jll v1.2.13+1 ⇒ v1.2.13+0
#   [8e850b90] ↓ libblastrampoline_jll v5.11.0+0 ⇒ v5.8.0+0
#   [3f19e933] ↓ p7zip_jll v17.4.0+2 ⇒ v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
#    Resolving package versions...
#     Updating `G:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\Project.toml`
#   [a6e380b2] + ControlSystems v1.15.2
#     Updating `G:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\Manifest.toml`
# ⌅ [47edcb42] + ADTypes v0.2.7
# ⌅ [79e6a3ab] ↓ Adapt v4.4.0 ⇒ v3.7.2
#   [ec485272] + ArnoldiMethod v0.4.0
# ⌅ [4c555306] + ArrayLayouts v1.10.4
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
# ⌃ [2a0fbf3d] + CPUSummary v0.2.6
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
# ⌅ [38540f10] + CommonSolve v0.2.4
#   [34da2185] + Compat v4.18.1
#   [2569d6c7] + ConcreteStructs v0.2.3
#   [a6e380b2] + ControlSystems v1.15.2
#   [aaaaaaaa] + ControlSystemsBase v1.20.2
#   [adafc99b] + CpuId v0.3.1
# ⌅ [864edb3b] + DataStructures v0.18.22
#   [e2d170a0] + DataValueInterfaces v1.0.0
# ⌅ [bcd4f6db] + DelayDiffEq v5.45.1
# ⌅ [2b5f629d] + DiffEqBase v6.145.6
# ⌅ [459566f4] + DiffEqCallbacks v2.36.1
#   [b4f34e82] + Distances v0.10.12
#   [4e289a0a] + EnumX v1.0.7
# ⌅ [f151be2c] + EnzymeCore v0.6.6
# ⌅ [d4d017d3] + ExponentialUtilities v1.25.0
#   [e2ba6199] + ExprTools v0.1.10
# ⌅ [7034ab61] + FastBroadcast v0.2.8
#   [9aa1b823] + FastClosures v0.3.2
# ⌅ [29a986be] + FastLapackInterface v2.0.4
# ⌅ [1a297f60] + FillArrays v1.14.0
#   [069b7b12] + FunctionWrappers v1.1.3
#   [77dc65aa] + FunctionWrappersWrappers v0.1.3
# ⌅ [d9f16b24] + Functors v0.4.12
# ⌅ [46192b85] + GPUArraysCore v0.1.5
#   [c145ed77] + GenericSchur v0.5.6
# ⌅ [86223c79] + Graphs v1.12.1
# ⌅ [3e5b6fbb] + HostCPUFeatures v0.1.17
#   [e91730f6] + Hungarian v0.7.0
#   [615f187c] + IfElse v0.1.1
#   [d25df0c9] + Inflate v0.1.5
#   [82899510] + IteratorInterfaceExtensions v1.0.0
# ⌅ [ef3ab10e] + KLU v0.4.1
# ⌅ [ba0b0d4f] + Krylov v0.9.10
#   [10f19ff3] + LayoutPointers v0.1.17
#   [50d2b5c4] + Lazy v0.15.1
# ⌅ [5078a376] + LazyArrays v1.10.0
# ⌅ [d3d80556] + LineSearches v7.4.1
#   [7a12625a] + LinearMaps v3.11.4
# ⌅ [7ed4a6bd] + LinearSolve v2.22.1
# ⌅ [bdcacae8] + LoopVectorization v0.12.172
#   [d125e4d3] + ManualMemory v0.1.8
# ⌅ [99c1a7ee] + MatrixEquations v2.4.5
# ⌅ [a3b82374] + MatrixFactorizations v2.2.0
# ⌅ [48965c70] + MatrixPencils v1.8.6
#   [bb5d69b7] + MaybeInplace v0.1.4
#   [46d2c3a1] + MuladdMacro v0.2.4
# ⌅ [d41bc354] + NLSolversBase v7.8.3
#   [2774e3e8] + NLsolve v4.5.1
# ⌅ [8913a72c] + NonlinearSolve v3.4.0
#   [6fe1bfb0] + OffsetArrays v1.17.0
# ⌅ [1dea7af3] + OrdinaryDiffEq v6.66.0
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [f517fe37] + Polyester v0.7.19
#   [1d0040c9] + PolyesterWeave v0.2.2
# ⌅ [f27b6e38] + Polynomials v4.0.21
# ⌅ [d236fae5] + PreallocationTools v0.4.13
# ⌅ [731186ca] + RecursiveArrayTools v3.3.3
# ⌅ [f2c3362d] + RecursiveFactorization v0.2.22
# ⌅ [7e49a35a] + RuntimeGeneratedFunctions v0.5.12
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.43
# ⌅ [0bca4576] + SciMLBase v2.15.2
# ⌅ [c0aeaf25] + SciMLOperators v0.3.7
# ⌅ [727e6d20] + SimpleNonlinearSolve v1.4.0
#   [699a6c99] + SimpleTraits v0.9.5
#   [ce78b400] + SimpleUnPack v1.1.0
# ⌅ [47a9eef4] + SparseDiffTools v2.18.0
# ⌅ [e56a9233] + Sparspak v0.3.11
# ⌅ [aedffcd0] + Static v0.8.9
# ⌅ [0d7ed370] + StaticArrayInterface v1.6.0
#   [82ae8749] + StatsAPI v1.8.0
#   [7792a7ef] + StrideArraysCore v0.5.8
# ⌅ [2efcf032] + SymbolicIndexingInterface v0.3.1
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.1
#   [8290d209] + ThreadingUtilities v0.5.5
# ⌅ [d5829a12] + TriangularSolve v0.1.20
#   [410a4b4d] + Tricks v0.1.13
#   [781d530d] + TruncatedStacktraces v1.4.0
# ⌅ [3d5dd08c] + VectorizationBase v0.21.71
#   [19fa3120] + VertexSafeGraphs v0.2.0
#   [1d5cc7b8] + IntelOpenMP_jll v2025.2.0+0
#   [856f044c] + MKL_jll v2025.2.0+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+1
#   [8ba89e20] + Distributed
#   [4af54fe1] + LazyArtifacts
#   [a63ad114] + Mmap
#   [1a1011a3] + SharedArrays
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
#    Resolving package versions...
#   No Changes to `G:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\Project.toml`
#   No Changes to `G:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\Manifest.toml`
#    Resolving package versions...
#     Updating `G:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\Project.toml`
#   [ab2f91bb] + OSQP v0.8.1
#     Updating `G:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v1.6.3
#   [523fee87] + CodecBzip2 v0.8.5
#   [0f8b85d8] + JSON3 v1.14.3
# ⌅ [b8f27783] + MathOptInterface v1.48.0
#   [d8a4904e] + MutableArithmetics v1.6.7
#   [ab2f91bb] + OSQP v0.8.1
#   [856f2bd8] + StructTypes v1.11.0
#   [9c4f68bf] + OSQP_jll v0.600.200+0
#   [9abbd945] + Profile
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ StructTypes
#   ✓ CodecBzip2
#   ✓ OSQP_jll
#   ✓ BenchmarkTools
#   ✓ MutableArithmetics
#   ✓ Polynomials → PolynomialsMutableArithmeticsExt
#   ✓ JSON3
#   ✓ MathOptInterface
#   ✓ OSQP
#   9 dependencies successfully precompiled in 41 seconds. 230 already precompiled.

# %%
using LinearAlgebra
using PyPlot
using SparseArrays
using ForwardDiff
using ControlSystems
using OSQP
# Out:
# ArgumentError: Package ForwardDiff not found in current path.
#
# - Run `import Pkg; Pkg.add("ForwardDiff")` to install the ForwardDiff package.
#
#
#
# Stacktrace:
#
#   [1] macro expansion
#
#     @ .\loading.jl:1630 [inlined]
#
#   [2] macro expansion
#
#     @ .\lock.jl:267 [inlined]
#
#   [3] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1611
#
#   [4] eval
#
#     @ .\boot.jl:370 [inlined]
#
#   [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:1903
#
#   [6] #invokelatest#2
#
#     @ .\essentials.jl:819 [inlined]
#
#   [7] invokelatest
#
#     @ .\essentials.jl:816 [inlined]
#
#   [8] (::VSCodeServer.var"#222#223"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#
#   [9] withpath(f::VSCodeServer.var"#222#223"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\VSCodeServer\src\repl.jl:303
#
#  [10] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#
#  [11] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\JSONRPC\src\typed.jl:68
#
#  [12] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#11#16"{String})
#
#     @ VSCodeServer c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#
#  [13] top-level scope
#
#     @ c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\notebook\notebook.jl:28

# %%
#Model parameters
g = 9.81 #m/s^2
m = 1.0 #kg 
ℓ = 0.3 #meters
J = 0.2*m*ℓ*ℓ

#Thrust limits
umin = [0.2*m*g; 0.2*m*g]
umax = [0.6*m*g; 0.6*m*g]

h = 0.05 #time step (20 Hz)
# Out:
# 0.05

# %%
#Planar Quadrotor Dynamics (x = [ x, y, theta, xdot ,ydot, theta_dot])
function quad_dynamics(x,u)
    θ = x[3]
    
    ẍ = (1/m)*(u[1] + u[2])*sin(θ)
    ÿ = (1/m)*(u[1] + u[2])*cos(θ) - g
    θ̈ = (1/J)*(ℓ/2)*(u[2] - u[1])
    
    return [x[4:6]; ẍ; ÿ; θ̈]
end
# Out:
# quad_dynamics (generic function with 1 method)

# %%
function quad_dynamics_rk4(x,u)
    #RK4 integration with zero-order hold on u
    f1 = quad_dynamics(x, u)
    f2 = quad_dynamics(x + 0.5*h*f1, u)
    f3 = quad_dynamics(x + 0.5*h*f2, u)
    f4 = quad_dynamics(x + h*f3, u)
    return x + (h/6.0)*(f1 + 2*f2 + 2*f3 + f4)
end
# Out:
# quad_dynamics_rk4 (generic function with 1 method)

# %%
#Linearized dynamics for hovering
x_hover = zeros(6)
u_hover = [0.5*m*g; 0.5*m*g]
A = ForwardDiff.jacobian(x->quad_dynamics_rk4(x,u_hover),x_hover);
B = ForwardDiff.jacobian(u->quad_dynamics_rk4(x_hover,u),u_hover);
quad_dynamics_rk4(x_hover, u_hover)
# Out:
# UndefVarError: `ForwardDiff` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:4

# %%
Nx = 6     # number of state
Nu = 2     # number of controls
Tfinal = 3.0 # final time
Nt = Int(Tfinal/h)+1    # number of time steps
thist = Array(range(0,h*(Nt-1), step=h));

# %%
# Cost weights
Q = Array(1.0*I(Nx));
R = Array(.01*I(Nu));
Qn = Array(1.0*I(Nx));

# %%
#Cost function
function cost(xhist,uhist)
    cost = 0.5*xhist[:,end]'*Qn*xhist[:,end]
    for k = 1:(size(xhist,2)-1)
        cost = cost + 0.5*xhist[:,k]'*Q*xhist[:,k] + 0.5*(uhist[k]'*R*uhist[k])[1]
    end
    return cost
end
# Out:
# cost (generic function with 1 method)

# %%
#LQR Hover Controller
P = dare(A,B,Q,R)
K = dlqr(A,B,Q,R)

function lqr_controller(t,x,K,xref)
    
    return u_hover - K*(x-xref)
end
# Out:
# UndefVarError: `dare` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:2

# %%
#Build QP matrices for OSQP
Nh = 20 #one second horizon at 20Hz
Nx = 6
Nu = 2
U = kron(Diagonal(I,Nh), [I zeros(Nu,Nx)]) #Matrix that picks out all u
Θ = kron(Diagonal(I,Nh), [0 0 0 0 1 0 0 0]) #Matrix that picks out all x3 (θ)
H = sparse([kron(Diagonal(I,Nh-1),[R zeros(Nu,Nx); zeros(Nx,Nu) Q]) zeros((Nx+Nu)*(Nh-1), Nx+Nu); zeros(Nx+Nu,(Nx+Nu)*(Nh-1)) [R zeros(Nu,Nx); zeros(Nx,Nu) P]])
b = zeros(Nh*(Nx+Nu))
C = sparse([[B -I zeros(Nx,(Nh-1)*(Nu+Nx))]; zeros(Nx*(Nh-1),Nu) [kron(Diagonal(I,Nh-1), [A B]) zeros((Nh-1)*Nx,Nx)] + [zeros((Nh-1)*Nx,Nx) kron(Diagonal(I,Nh-1),[zeros(Nx,Nu) Diagonal(-I,Nx)])]])

#Dynamics + Thrust limit constraints
D = [C; U]
lb = [zeros(Nx*Nh); kron(ones(Nh),umin-u_hover)]
ub = [zeros(Nx*Nh); kron(ones(Nh),umax-u_hover)]

#Dynamics + thrust limit + bound constraint on θ to keep the system within small-angle approximation
#D = [C; U; Θ]
#lb = [zeros(Nx*Nh); kron(ones(Nh),umin-u_hover); -0.2*ones(Nh)]
#ub = [zeros(Nx*Nh); kron(ones(Nh),umax-u_hover); 0.2*ones(Nh)]

prob = OSQP.Model()
OSQP.setup!(prob; P=H, q=b, A=D, l=lb, u=ub, verbose=false, eps_abs=1e-8, eps_rel=1e-8, polish=1);
# Out:
# UndefVarError: `P` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X13sZmlsZQ==.jl:7

# %%
#MPC Controller
function mpc_controller(t,x,xref)
    
    #Update QP problem
    lb[1:6] .= -A*x
    ub[1:6] .= -A*x
    
    for j = 1:(Nh-1)
        b[(Nu+(j-1)*(Nx+Nu)).+(1:Nx)] .= -Q*xref
    end
    b[(Nu+(Nh-1)*(Nx+Nu)).+(1:Nx)] .= -Q*xref
    
    OSQP.update!(prob, q=b, l=lb, u=ub)

    #Solve QP
    results = OSQP.solve!(prob)
    Δu = results.x[1:Nu]

    return u_hover + Δu
end
# Out:
# mpc_controller (generic function with 1 method)

# %%
function closed_loop(x0,controller,N)
    xhist = zeros(length(x0),N)
    u0 = controller(1,x0)
    uhist = zeros(length(u0),N-1)
    uhist[:,1] .= u0
    xhist[:,1] .= x0
    for k = 1:(N-1)
        uk = controller(k,xhist[:,k])
        uhist[:,k] = max.(min.(umax, uk), umin) #enforce control limits
        xhist[:,k+1] .= quad_dynamics_rk4(xhist[:,k],uhist[:,k])
    end
    return xhist, uhist
end
# Out:
# closed_loop (generic function with 1 method)

# %%
x_ref = [0.0; 1.0; 0; 0; 0; 0]
x0 = [1.0; 2.0; 0.0; 0; 0; 0]
xhist1, uhist1 = closed_loop(x0, (t,x)->lqr_controller(t,x,K,x_ref), Nt);
xhist2, uhist2 = closed_loop(x0, (t,x)->mpc_controller(t,x,x_ref), Nt);
# Out:
# UndefVarError: `lqr_controller` not defined
#
#
#
# Stacktrace:
#
#  [1] (::var"#25#26")(t::Int64, x::Vector{Float64})
#
#    @ Main g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X16sZmlsZQ==.jl:3
#
#  [2] closed_loop(x0::Vector{Float64}, controller::var"#25#26", N::Int64)
#
#    @ Main g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:3
#
#  [3] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X16sZmlsZQ==.jl:3

# %%
plot(thist,xhist1[1,:], label="x LQR")
plot(thist,xhist2[1,:], label="x MPC")
xlabel("time")
legend()
# Out:
# UndefVarError: `xhist1` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sZmlsZQ==.jl:1

# %%
plot(thist,xhist1[2,:], label="y LQR")
plot(thist,xhist2[2,:], label="y MPC")
xlabel("time")
legend()
# Out:
# UndefVarError: `xhist1` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X21sZmlsZQ==.jl:1

# %%
plot(thist,xhist1[3,:], label="θ LQR")
plot(thist,xhist2[3,:], label="θ MPC")
xlabel("time")
legend()
# Out:
# UndefVarError: `xhist1` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X22sZmlsZQ==.jl:1

# %%
plot(thist[1:end-1], uhist1[1,:], label="u1 LQR")
plot(thist[1:end-1], uhist2[1,:], label="u1 MPC")
xlabel("Time")
legend()
# Out:
# UndefVarError: `uhist1` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X23sZmlsZQ==.jl:1

# %%
plot(thist[1:end-1], uhist1[2,:], label="u2 LQR")
plot(thist[1:end-1], uhist2[2,:], label="u2 MPC")
xlabel("Time")
legend()
# Out:
# UndefVarError: `uhist1` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X24sZmlsZQ==.jl:1

# %%
#Set up visualization
using MeshCat
using RobotZoo: Quadrotor, PlanarQuadrotor
using CoordinateTransformations, Rotations, Colors, StaticArrays, RobotDynamics

function set_mesh!(vis, model::L;
        scaling=1.0, color=colorant"black"
    ) where {L <: Union{Quadrotor, PlanarQuadrotor}} 
    # urdf_folder = joinpath(@__DIR__, "..", "data", "meshes")
    urdf_folder = @__DIR__
    # if scaling != 1.0
    #     quad_scaling = 0.085 * scaling
    obj = joinpath(urdf_folder, "quadrotor_scaled.obj")
    if scaling != 1.0
        error("Scaling not implemented after switching to MeshCat 0.12")
    end
    robot_obj = MeshFileGeometry(obj)
    mat = MeshPhongMaterial(color=color)
    setobject!(vis["robot"]["geom"], robot_obj, mat)
    if hasfield(L, :ned)
        model.ned && settransform!(vis["robot"]["geom"], LinearMap(RotX(pi)))
    end
end

function visualize!(vis, model::PlanarQuadrotor, x::StaticVector)
    py,pz = x[1], x[2]
    θ = x[3]
    settransform!(vis["robot"], compose(Translation(0,py,pz), LinearMap(RotX(-θ))))
end

function visualize!(vis, model, tf::Real, X)
    fps = Int(round((length(X)-1)/tf))
    anim = MeshCat.Animation(vis; fps)
    for (k,x) in enumerate(X)
        atframe(anim, k) do
            x = X[k]
            visualize!(vis, model, SVector{6}(x)) 
        end
    end
    setanimation!(vis, anim)
end
# Out:
# ArgumentError: Package Colors not found in current path.
#
# - Run `import Pkg; Pkg.add("Colors")` to install the Colors package.
#
#
#
# Stacktrace:
#
#   [1] macro expansion
#
#     @ .\loading.jl:1630 [inlined]
#
#   [2] macro expansion
#
#     @ .\lock.jl:267 [inlined]
#
#   [3] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1611
#
#   [4] eval
#
#     @ .\boot.jl:370 [inlined]
#
#   [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:1903
#
#   [6] #invokelatest#2
#
#     @ .\essentials.jl:819 [inlined]
#
#   [7] invokelatest
#
#     @ .\essentials.jl:816 [inlined]
#
#   [8] (::VSCodeServer.var"#222#223"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#
#   [9] withpath(f::VSCodeServer.var"#222#223"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\VSCodeServer\src\repl.jl:303
#
#  [10] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#
#  [11] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\JSONRPC\src\typed.jl:68
#
#  [12] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#11#16"{String})
#
#     @ VSCodeServer c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#
#  [13] top-level scope
#
#     @ c:\Users\ggory\.vscode\extensions\julialang.language-julia-1.187.2\scripts\notebook\notebook.jl:28

# %%
vis = Visualizer()
model = PlanarQuadrotor()
set_mesh!(vis, model)
render(vis)
# Out:
# ┌ Info: Listening on: 127.0.0.1:8702, thread id: 1
# └ @ HTTP.Servers C:\Users\ggory\.julia\packages\HTTP\ShTJs\src\Servers.jl:382
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# │ http://127.0.0.1:8702
# └ @ MeshCat C:\Users\ggory\.julia\packages\MeshCat\4DqVC\src\visualizer.jl:39
# UndefVarError: `set_mesh!` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X26sZmlsZQ==.jl:3

# %%
X1 = [SVector{6}(x) for x in eachcol(xhist1)];
X2 = [SVector{6}(x) for x in eachcol(xhist2)];
# Out:
# UndefVarError: `xhist1` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X30sZmlsZQ==.jl:1

# %%
visualize!(vis, model, thist[end], X1)
# Out:
# UndefVarError: `visualize!` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X31sZmlsZQ==.jl:1

# %%
visualize!(vis, model, thist[end], X2)
# Out:
# UndefVarError: `visualize!` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ g:\내 드라이브\RCI Lab\10. 수업 준비\7. 로봇 최적 제어 및 러닝 제어\Lecture #14. Linear MPC\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X32sZmlsZQ==.jl:1
