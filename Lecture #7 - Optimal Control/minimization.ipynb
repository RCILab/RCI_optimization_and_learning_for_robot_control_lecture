# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate()
# Out:
#   Activating project at `C:\Users\ggory\Downloads\lecture-notebooks-main\lecture-notebooks-main\Lecture 3`

# %%
using LinearAlgebra
using ForwardDiff
using PyPlot

# %%
function f(x)
    return x.^4 + x.^3 - x.^2 - x
end
# Out:
# f (generic function with 1 method)

# %%
function ∇f(x)
    return 4.0*x.^3 + 3.0*x.^2 - 2.0*x - 1.0
end
# Out:
# ∇f (generic function with 1 method)

# %%
function ∇2f(x)
    return 12.0*x.^2 + 6.0*x - 2.0
end
# Out:
# ∇2f (generic function with 1 method)

# %%
x = LinRange(-1.75,1.25,1000)
# Out:
# 1000-element LinRange{Float64, Int64}:
#  -1.75, -1.747, -1.74399, -1.74099, …, 1.24099, 1.24399, 1.247, 1.25

# %%
p = plot(x,f(x))
# Out:
# UndefVarError: `plot` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:1
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489

# %%
function newton_step(x0)
    xn = x0 - ∇2f(x0)\∇f(x0)
end
# Out:
# newton_step (generic function with 1 method)

# %%
xguess = 0.0
plot(x, f(x))
plot(xguess, f(xguess), "rx")
# Out:
# UndefVarError: `plot` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[7]:2
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489

# %%
xnew = newton_step(xguess[end])
xguess = [xguess xnew]
plot(x, f(x))
plot(xguess, f(xguess), "rx")
# Out:
# UndefVarError: `plot` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[8]:3
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489

# %%
∇2f(0.0)

# %%
function regularized_newton_step(x0)
    β = 1.0
    H = ∇2f(x0)
    while !isposdef(H)
        H = H + β*I
    end
    xn = x0 - H\∇f(x0)
end

# %%
xguess = 0.0
plot(x, f(x))
plot(xguess, f(xguess), "rx")

# %%
xnew = regularized_newton_step(xguess[end])
xguess = [xguess xnew]
plot(x, f(x))
plot(xguess, f(xguess), "rx")
